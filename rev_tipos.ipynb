# %% [markdown]
# <a href="https://colab.research.google.com/github/Juuj3/tipos_de_dados_py_3F/blob/main/rev_tipos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#revisão de variaveis e tipos de dados
#tipos básicos

#int: números inteiros (sem casa decimais)
idade = 15

#float: ponto flutuante (com casas decimais)
altura: 1.75

#string: (ou str) texto puro
nome = "Guilherme Henrique da Silva"

#bool: booleano (sim, nao, verdade, mentira, true, false)
estudante = True

#tipos de coleção
#lista coleção ordenada
frutas = ["maça", "banana", "uva", "pera"]

#tupla, geralmente usada para guardar coordenadas
cianorte = (-23.6631, -52.6054)

#set (conjunto de dados nao repetitivos)
numeros = {1,2,3,4,5}

#dic (dicionario)
pessoa = {"nome": "Guilherme", "idade": 15, "altura": 1.75}

#none type, quando algo precisa ser nulo
valor = None
